# %%
import torch
from IPython.display import Image, clear_output  # to display images


clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.6.0 CPU

# %%
import yaml
with open("C:\yolo\data\data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
num_classes
# Out:
# '4'

# %%
with open('C:\yolo\yolov5\models/yolov5x.yaml') as f:
    yolo= yaml.load(f, Loader=yaml.FullLoader)


yolo
# Out:
# {'nc': 80,
#  'depth_multiple': 1.33,
#  'width_multiple': 1.25,
#  'anchors': [[10, 13, 16, 30, 33, 23],
#   [30, 61, 62, 45, 59, 119],
#   [116, 90, 156, 198, 373, 326]],
#  'backbone': [[-1, 1, 'Focus', [64, 3]],
#   [-1, 1, 'Conv', [128, 3, 2]],
#   [-1, 3, 'BottleneckCSP', [128]],
#   [-1, 1, 'Conv', [256, 3, 2]],
#   [-1, 9, 'BottleneckCSP', [256]],
#   [-1, 1, 'Conv', [512, 3, 2]],
#   [-1, 9, 'BottleneckCSP', [512]],
#   [-1, 1, 'Conv', [1024, 3, 2]],
#   [-1, 1, 'SPP', [1024, [5, 9, 13]]],
#   [-1, 3, 'BottleneckCSP', [1024, False]]],
#  'head': [[-1, 1, 'Conv', [512, 1, 1]],
#   [-1, 1, 'nn.Upsample', ['None', 2, 'nearest']],
#   [[-1, 6], 1, 'Concat', [1]],
#   [-1, 3, 'BottleneckCSP', [512, False]],
#   [-1, 1, 'Conv', [256, 1, 1]],
#   [-1, 1, 'nn.Upsample', ['None', 2, 'nearest']],
#   [[-1, 4], 1, 'Concat', [1]],
#   [-1, 3, 'BottleneckCSP', [256, False]],
#   [-1, 1, 'Conv', [256, 3, 2]],
#   [[-1, 14], 1, 'Concat', [1]],
#   [-1, 3, 'BottleneckCSP', [512, False]],
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# Reusing TensorBoard on port 6006 (pid 22396), started 0:17:38 ago. (Use '!kill 22396' to kill it.)
#       <iframe id="tensorboard-frame-c023b78bdeb71c14" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c023b78bdeb71c14");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %%time
# !python train.py --img 416 --batch 10 --epochs 100 --data C:\yolo\data.yaml --cfg C:/yolo/yolov5/models/yolov5l.yaml  --name results  --cache --noautoanchor
# Out:
# ['runs\\exp0_yolov5x_results', 'runs\\exp1', 'runs\\exp2_results', 'runs\\exp3_results', 'runs\\exp4']
#
#                  all           2           0           0           0           0           0
#                  all           2           0           0           0           0           0
#                  all           2           0           0           0           0           0
#                  all           2           0           0           0           0           0
#                  all           2           0           0           0           0           0
#                  all           2           0           0           0           0           0
#                  all           2          90           0           0    0.000167    1.67e-05
#                  all           2          90           0           0    0.000167    1.67e-05
# Wall time: 1h 14min 56s
# Using CPU
#
# ...

# %%
train.py --noautoanchor,
# Out:
# 'C:\\yolo\\yolov5'

# %%
# !python train.py --data C:\yolo\data.yaml --cfg C:/yolo/yolov5/models/yolov5l.yaml --weights '' --batch-size 2 --noautoanchor
# Out:
# ^C
